# %%
# %sql
-- You can set a managed storage location when creating catalog
CREATE CATALOG IF NOT EXISTS healthcare
MANAGED LOCATION 'abfss://mycatalogdev@mpmypracticesadev.dfs.core.windows.net/';

# %%
# %sql
USE CATALOG healthcare

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS silver

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS gold
